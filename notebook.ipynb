# %%
# !pip install pandas
# Out:
# ...
# [notice] A new release of pip is available: 26.0.1 -> 26.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
a=[1, 2, 3, 4, 5]
type(a)
# Out:
# list

# %%
x= 10
print(x)
# Out:
# 10

# %%
number = input("Enter a number: ")
print(f"You entered: {number}")
# Out:
# You entered: 5

# %%
stories = {
    1: "Harry Poter",
    2: "Send me to heaven"
}
for number, name in stories.items():
    print(number)
# Out:
# 1
# 2

# %%
# Numpy used for fast numerical computing
import numpy as np

np_array = np.array([i for i in range(5)])
np_array+=5
print(np_array)
np_array.shape
np_array= np.array([[1, 2, 3], [4, 5, 6]])
np_array.shape

np_array = np.array([1, 2, 3, 4, 5], dtype=np.float32)
print(np_array)

np_array = np.zeros((2, 3))
np_array = np.ones((2, 3))
np_array = np.full((2, 3),5)
print(np_array)
np_array = np.eye(3)
print(np_array)
np_array = np.random.random((2, 3))
print(np_array)
np_array = np.random.randint(0, 10, (2, 5))
print(np_array)
#np_array = np.linspace(0, 10, 1000)
#print(np_array)
np_array = np.arange(0, 10, 0.5)
print(np_array)
c = np.random.randint(0,10, (2,5))
print(c.dtype)
list = [1, 2, 3, 4, 5]
list1 = [6, 7, 8, 9, 10]
#print(list + list1)
np_array1 = np.array(list)
np_array2 = np.array(list1)
print(np.divide(np_array1, np_array2))
array = np.array([[1, 2, 3], [4, 5, 6]])
#transposed_array = np.transpose(array)
#print(transposed_array)
transposed_array = array.T
print(transposed_array)

print(array.shape)
reshaped_array = array.reshape(3, 2)
print(reshaped_array)
# Out:
# [5 6 7 8 9]
# [1. 2. 3. 4. 5.]
# [[5 5 5]
#  [5 5 5]]
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# [[0.01832208 0.63379931 0.47483684]
#  [0.7394196  0.69937075 0.37919351]]
# [[6 5 0 9 5]
#  [9 7 1 0 3]]
# [0.  0.5 1.  1.5 2.  2.5 3.  3.5 4.  4.5 5.  5.5 6.  6.5 7.  7.5 8.  8.5
#  9.  9.5]
# int32
# [0.16666667 0.28571429 0.375      0.44444444 0.5       ]
# [[1 4]
#  [2 5]
#  [3 6]]
# (2, 3)
# [[1 2]
#  [3 4]
#  [5 6]]

# %%
# !pip install scikit-learn
# Out:
# ...
# [notice] A new release of pip is available: 26.0.1 -> 26.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# pandas used for data manipulation and analysis
import pandas as pd

# %%
from sklearn.datasets import load_diabetes
diabetes_dataset = load_diabetes()

type(diabetes_dataset)

print(diabetes_dataset)
# Out:
# {'data': array([[ 0.03807591,  0.05068012,  0.06169621, ..., -0.00259226,
#          0.01990749, -0.01764613],
#        [-0.00188202, -0.04464164, -0.05147406, ..., -0.03949338,
#         -0.06833155, -0.09220405],
#        [ 0.08529891,  0.05068012,  0.04445121, ..., -0.00259226,
#          0.00286131, -0.02593034],
#        ...,
#        [ 0.04170844,  0.05068012, -0.01590626, ..., -0.01107952,
#         -0.04688253,  0.01549073],
#        [-0.04547248, -0.04464164,  0.03906215, ...,  0.02655962,
#          0.04452873, -0.02593034],
#        [-0.04547248, -0.04464164, -0.0730303 , ..., -0.03949338,
#         -0.00422151,  0.00306441]], shape=(442, 10)), 'target': array([151.,  75., 141., 206., 135.,  97., 138.,  63., 110., 310., 101.,
#         69., 179., 185., 118., 171., 166., 144.,  97., 168.,  68.,  49.,
#         68., 245., 184., 202., 137.,  85., 131., 283., 129.,  59., 341.,
#         87.,  65., 102., 265., 276., 252.,  90., 100.,  55.,  61.,  92.,
# ...

# %%
diabetes_df = pd.DataFrame(diabetes_dataset.data, columns=diabetes_dataset.feature_names)
diabetes_df.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6
# 0 -0.002592  0.019907 -0.017646
# 1 -0.039493 -0.068332 -0.092204
# 2 -0.002592  0.002861 -0.025930
# 3  0.034309  0.022688 -0.009362
# 4 -0.002592 -0.031988 -0.046641

# %%
diabetes_df.shape
# Out:
# (442, 10)

# %%
#diabetes_df = pd.read_csv("diabetes.csv")
#diabetes_df.head()

# %%
diabetes_df.tail()
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#            s4        s5        s6
# 437 -0.002592  0.031193  0.007207
# 438  0.034309 -0.018114  0.044485
# 439 -0.011080 -0.046883  0.015491
# 440  0.026560  0.044529 -0.025930
# 441 -0.039493 -0.004222  0.003064

# %%
diabetes_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 442 entries, 0 to 441
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   age     442 non-null    float64
#  1   sex     442 non-null    float64
#  2   bmi     442 non-null    float64
#  3   bp      442 non-null    float64
#  4   s1      442 non-null    float64
#  5   s2      442 non-null    float64
#  6   s3      442 non-null    float64
#  7   s4      442 non-null    float64
#  8   s5      442 non-null    float64
#  9   s6      442 non-null    float64
# dtypes: float64(10)
# memory usage: 34.7 KB

# %%
#diabetes_df.notnull().sum()

# %%
#diabetes_df = pd.read_csv("diabetes.csv")
#diabetes_df.value_counts("Age")

# %%
#diabetes_df.groupby("Outcome").mean()

# %%
diabetes_df.count()
# Out:
# age    442
# sex    442
# bmi    442
# bp     442
# s1     442
# s2     442
# s3     442
# s4     442
# s5     442
# s6     442
# dtype: int64

# %%
diabetes_df.mean()
# Out:
# age   -2.511817e-19
# sex    1.230790e-17
# bmi   -2.245564e-16
# bp    -4.797570e-17
# s1    -1.381499e-17
# s2     3.918434e-17
# s3    -5.777179e-18
# s4    -9.042540e-18
# s5     9.268604e-17
# s6     1.130318e-17
# dtype: float64

# %%
# Standard Deviation is a measure of the amount of variation from the mean.
diabetes_df.std()
# Out:
# age    0.047619
# sex    0.047619
# bmi    0.047619
# bp     0.047619
# s1     0.047619
# s2     0.047619
# s3     0.047619
# s4     0.047619
# s5     0.047619
# s6     0.047619
# dtype: float64

# %%
diabetes_df.min()
diabetes_df.max()
# Out:
# age    0.110727
# sex    0.050680
# bmi    0.170555
# bp     0.132044
# s1     0.153914
# s2     0.198788
# s3     0.181179
# s4     0.185234
# s5     0.133597
# s6     0.135612
# dtype: float64

# %%
diabetes_df.describe()
# Out:
#                 age           sex           bmi            bp            s1  \
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean  -2.511817e-19  1.230790e-17 -2.245564e-16 -4.797570e-17 -1.381499e-17
# std    4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02
# min   -1.072256e-01 -4.464164e-02 -9.027530e-02 -1.123988e-01 -1.267807e-01
# 25%   -3.729927e-02 -4.464164e-02 -3.422907e-02 -3.665608e-02 -3.424784e-02
# 50%    5.383060e-03 -4.464164e-02 -7.283766e-03 -5.670422e-03 -4.320866e-03
# 75%    3.807591e-02  5.068012e-02  3.124802e-02  3.564379e-02  2.835801e-02
# max    1.107267e-01  5.068012e-02  1.705552e-01  1.320436e-01  1.539137e-01
#
#                  s2            s3            s4            s5            s6
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean   3.918434e-17 -5.777179e-18 -9.042540e-18  9.268604e-17  1.130318e-17
# ...

# %%
diabetes_df['Outcome'] = diabetes_dataset.target
diabetes_df.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6  Outcome
# 0 -0.002592  0.019907 -0.017646    151.0
# 1 -0.039493 -0.068332 -0.092204     75.0
# 2 -0.002592  0.002861 -0.025930    141.0
# 3  0.034309  0.022688 -0.009362    206.0
# 4 -0.002592 -0.031988 -0.046641    135.0

# %%
diabetes_df.drop(index=0, axis=0)
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# 5   -0.092695 -0.044642 -0.040696 -0.019442 -0.068991 -0.079288  0.041277
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#            s4        s5        s6  Outcome
# ...

# %%
diabetes_df.drop('Outcome', axis=1)
diabetes_df.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6  Outcome
# 0 -0.002592  0.019907 -0.017646    151.0
# 1 -0.039493 -0.068332 -0.092204     75.0
# 2 -0.002592  0.002861 -0.025930    141.0
# 3  0.034309  0.022688 -0.009362    206.0
# 4 -0.002592 -0.031988 -0.046641    135.0

# %%
diabetes_df.iloc[0]
# Out:
# age          0.038076
# sex          0.050680
# bmi          0.061696
# bp           0.021872
# s1          -0.044223
# s2          -0.034821
# s3          -0.043401
# s4          -0.002592
# s5           0.019907
# s6          -0.017646
# Outcome    151.000000
# Name: 0, dtype: float64

# %%
# All rows and first column
print(diabetes_df.iloc[:,0])
# Out:
# 0      0.038076
# 1     -0.001882
# 2      0.085299
# 3     -0.089063
# 4      0.005383
#          ...
# 437    0.041708
# 438   -0.005515
# 439    0.041708
# 440   -0.045472
# 441   -0.045472
# Name: age, Length: 442, dtype: float64

# %%
print(diabetes_df.iloc[:,-1])
# Out:
# 0      151.0
# 1       75.0
# 2      141.0
# 3      206.0
# 4      135.0
#        ...
# 437    178.0
# 438    104.0
# 439    132.0
# 440    220.0
# 441     57.0
# Name: Outcome, Length: 442, dtype: float64

# %%
# Correlation is a statistical measure that 
# indicates the extent to which two or more variables fluctuate together.
# A positive correlation indicates that as one variable increases, the other variable tends to increase as well,
# while a negative correlation indicates that as one variable increases, the other variable tends to decrease.
# A correlation coefficient ranges from -1 to 1, where -1 indicates a perfect negative correlation, 0 indicates no correlation, and 1 indicates a perfect positive correlation.

diabetes_df.corr()
# Out:
#               age       sex       bmi        bp        s1        s2        s3  \
# age      1.000000  0.173737  0.185085  0.335428  0.260061  0.219243 -0.075181
# sex      0.173737  1.000000  0.088161  0.241010  0.035277  0.142637 -0.379090
# bmi      0.185085  0.088161  1.000000  0.395411  0.249777  0.261170 -0.366811
# bp       0.335428  0.241010  0.395411  1.000000  0.242464  0.185548 -0.178762
# s1       0.260061  0.035277  0.249777  0.242464  1.000000  0.896663  0.051519
# s2       0.219243  0.142637  0.261170  0.185548  0.896663  1.000000 -0.196455
# s3      -0.075181 -0.379090 -0.366811 -0.178762  0.051519 -0.196455  1.000000
# s4       0.203841  0.332115  0.413807  0.257650  0.542207  0.659817 -0.738493
# s5       0.270774  0.149916  0.446157  0.393480  0.515503  0.318357 -0.398577
# s6       0.301731  0.208133  0.388680  0.390430  0.325717  0.290600 -0.273697
# Outcome  0.187889  0.043062  0.586450  0.441482  0.212022  0.174054 -0.394789
#
# ...

# %%
# Matplotlib
# !pip install matplotlib
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 10, 100)
y = np.sin(x)
z= np.cos(x)
plt.plot(x, y, label='Sine')
plt.xlabel('Angle')
plt.ylabel('Sine Value')
plt.title('Sine Wave')
plt.legend()
plt.show()

# %%
x= np.linspace(-10,10,20)
y = x**2
plt.plot(x,y, 'g.')
plt.show()

# %%
fig = plt.figure()
#[left, bottom, width, height]
ax = fig.add_axes([0, 0, 1, 1])
languages = ['English', 'Spanish', 'French', 'German', 'Chinese']
people = [100, 80, 60, 40, 20]
ax.bar(languages, people)
# Out:
# <BarContainer object of 5 artists>

# %%
fig = plt.figure()
#[left, bottom, width, height]
ax = fig.add_axes([0, 0, 1, 1])
ax.pie(people, labels=languages, autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1ace159fcb0>,
# ...
#  [Text(0.5499999722395388, 0.9526279601903919, 'English'),
#   Text(-1.075962433995059, 0.22870251557739363, 'Spanish'),
#   Text(-0.33991831634615544, -1.046162290570825, 'French'),
#   Text(0.7360437908666487, -0.8174591964903528, 'German'),
#   Text(1.0759624539888648, -0.2287024215137656, 'Chinese')],
#  [Text(0.29999998485793017, 0.5196152510129409, '33.3%'),
#   Text(-0.5868886003609413, 0.12474682667857832, '26.7%'),
#   Text(-0.1854099907342666, -0.5706339766749954, '20.0%'),
#   Text(0.40147843138180833, -0.4458868344492833, '13.3%'),
#   Text(0.5868886112666535, -0.12474677537114486, '6.7%')])

# %%
x = np.linspace(0, 10, 100)
y = np.sin(x)
z= np.cos(x)
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])
ax.scatter(x, y, label='Sine', color='blue')
ax.scatter(x, z, label='Cosine', color='orange')

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
z = 20 * np.random.random(100)
x= np.sin(z)
y= np.cos(z)
ax.scatter(x, y, z, c=z, cmap='viridis')

# %%
#!pip install seaborn
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.relplot(x='total_bill', y='tip', data=tips, hue='day', style='time')

# %%
sns.set_theme()
sns.relplot(x='total_bill', y='tip', data=tips, hue='day', style='time')

# %%
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.scatterplot(x='sepal_length', y='sepal_width', data=iris, hue='species')
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.countplot(x='species', data=iris)
# Out:
# <Axes: xlabel='species', ylabel='count'>

# %%
iris.shape
# Out:
# (150, 5)

# %%
sns.barplot(x='species', y='sepal_length', hue='species', data=iris)
# Out:
# <Axes: xlabel='species', ylabel='sepal_length'>

# %%
sns.displot(iris['sepal_length'])

# %%
plt.figure(figsize=(10, 6) )
correlation_matrix = iris.select_dtypes(include=[np.number]).corr()
sns.heatmap( correlation_matrix, annot=True, fmt='.1f', cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# Missing values
# #1 Imputation
# #2 Dropping
#
# Central tendencies
# 1. Mean
# 2. Median
# 3. Mode

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

diabetes_dataset = pd.read_csv("synthetic_dataset.csv")

diabetes_dataset.head()

diabetes_dataset.notnull().sum()

#diabetes_dataset.shape

diabetes_dataset.head(10)

#diabetes_dataset.isnull().sum()

#diabetes_dataset
# Out:
#   Category   Price    Rating         Stock  Discount
# 0      NaN  5548.0  1.870322           NaN       0.0
# 1      NaN  3045.0  4.757798           NaN      38.0
# 2      NaN  4004.0       NaN      In Stock       0.0
# 3      NaN  4808.0  1.492085           NaN      33.0
# 4      NaN  1817.0       NaN  Out of Stock      23.0
# 5      NaN  3522.0       NaN           NaN       NaN
# 6        C   667.0  3.668341      In Stock      41.0
# 7        A  7125.0  4.983998  Out of Stock       7.0
# 8        A  2777.0  2.678384      In Stock       6.0
# 9      NaN   463.0  4.626187           NaN       3.0

# %%
fig, ax = plt.subplots(figsize=(8, 8))
sns.displot(diabetes_dataset.Discount)

# %%
diabetes_dataset.fillna({ 'Category': diabetes_dataset['Category'].mode()[0] }, inplace=True)
# Out:
#      Category   Price    Rating         Stock  Discount
# 0           C  5548.0  1.870322           NaN       0.0
# 1           C  3045.0  4.757798           NaN      38.0
# 2           C  4004.0       NaN      In Stock       0.0
# 3           C  4808.0  1.492085           NaN      33.0
# 4           C  1817.0       NaN  Out of Stock      23.0
# ...       ...     ...       ...           ...       ...
# 4357        C  4436.0  4.728335           NaN      49.0
# 4358        B  6236.0       NaN  Out of Stock       4.0
# 4359        C  3283.0       NaN  Out of Stock       9.0
# 4360        D  2999.0  4.425995           NaN      40.0
# 4361        C     NaN  2.184471           NaN       0.0
#
# [4362 rows x 5 columns]

# %%
diabetes_dataset.fillna({'Stock': diabetes_dataset['Stock'].median()}, inplace=True)

# %%
sns.heatmap(diabetes_dataset.isna(), cbar=False)
# Out:
# <Axes: >

# %%
sns.histplot(diabetes_dataset['Discount'], kde=True)
# Out:
# <Axes: xlabel='Discount', ylabel='Count'>

# %%
sns.boxplot(x='Discount', data=diabetes_dataset)
# Out:
# <Axes: xlabel='Discount'>

# %%
diabetes_dataset.isnull().dropna(how='any')
# Out:
#       Category  Price  Rating  Stock  Discount
# 0        False  False   False   True     False
# 1        False  False   False   True     False
# 2        False  False    True  False     False
# 3        False  False   False   True     False
# 4        False  False    True  False     False
# ...        ...    ...     ...    ...       ...
# 4357     False  False   False   True     False
# 4358     False  False    True  False     False
# 4359     False  False    True  False     False
# 4360     False  False   False   True     False
# 4361     False   True   False   True     False
#
# [4362 rows x 5 columns]

# %% [markdown]
# Data Standardizing
# The process of standardizing the data to a common format and common range

# %%
import sklearn as skLearn

ds = skLearn.datasets.load_breast_cancer()
df = pd.DataFrame(data = ds.data, columns=ds.feature_names)
df['HasCancer'] = ds.target
df.head(10)
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
# 5        12.45         15.70           82.57      477.1          0.12780
# 6        18.25         19.98          119.60     1040.0          0.09463
# 7        13.71         20.83           90.20      577.9          0.11890
# 8        13.00         21.82           87.50      519.8          0.12730
# 9        12.46         24.04           83.97      475.9          0.11860
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760         0.30010              0.14710         0.2419
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X= df
Y = ds.target

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=3)

# %%
print(ds.data.std())
# Out:
# 228.29740508276657

# %%
scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
scaler.transform(X_train).std()
# Out:
# np.float64(1.0)

# %% [markdown]
# Label Encoding

# %%
diabetes_df = pd.read_csv("synthetic_dataset.csv")
diabetes_df.head()
# Out:
#   Category   Price    Rating         Stock  Discount
# 0      NaN  5548.0  1.870322           NaN       0.0
# 1      NaN  3045.0  4.757798           NaN      38.0
# 2      NaN  4004.0       NaN      In Stock       0.0
# 3      NaN  4808.0  1.492085           NaN      33.0
# 4      NaN  1817.0       NaN  Out of Stock      23.0

# %%
diabetes_df['Stock'].value_counts()
# Out:
# Stock
# In Stock        1513
# Out of Stock    1497
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder


label_encode = LabelEncoder()

labels = label_encode.fit_transform(diabetes_df['Stock'])

diabetes_df['Target'] = labels

diabetes_df.head()
# Out:
#   Category   Price    Rating         Stock  Discount  Target
# 0      NaN  5548.0  1.870322           NaN       0.0       2
# 1      NaN  3045.0  4.757798           NaN      38.0       2
# 2      NaN  4004.0       NaN      In Stock       0.0       0
# 3      NaN  4808.0  1.492085           NaN      33.0       2
# 4      NaN  1817.0       NaN  Out of Stock      23.0       1

# %% [markdown]
# Imbalanced Dataset
# A dataset with an unequal class distribution

# %%
diabetes_df['Discount'].value_counts()
# Out:
# Discount
# 15.0    104
# 45.0     98
# 41.0     93
# 7.0      92
# 28.0     92
# 5.0      92
# 20.0     89
# 27.0     88
# 23.0     87
# 40.0     86
# 31.0     86
# 39.0     85
# 13.0     85
# 30.0     84
# 49.0     84
# 17.0     83
# 34.0     83
# 33.0     82
# 6.0      82
# 35.0     81
# 0.0      80
# 3.0      80
# 19.0     80
# 1.0      79
# 44.0     78
# 24.0     78
# 21.0     77
# 36.0     77
# 10.0     76
# 42.0     76
# 37.0     76
# 32.0     76
# 25.0     75
# 16.0     75
# 47.0     74
# 14.0     74
# 2.0      74
# 18.0     74
# 9.0      74
# 29.0     73
# 22.0     73
# 4.0      72
# 38.0     71
# 26.0     71
# 11.0     71
# 12.0     69
# 43.0     68
# 48.0     67
# 46.0     66
# 8.0      60
# Name: count, dtype: int64

# %%
ds = skLearn.datasets.load_breast_cancer()
df = pd.DataFrame(data = ds.data, columns=ds.feature_names)

df.head()

df['HasCancer'] = ds.target
df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# ...

# %%
df['HasCancer'].value_counts()
# Out:
# HasCancer
# 1    357
# 0    212
# Name: count, dtype: int64

# %% [markdown]
# # Undersampling
# remove randomly samples from the majority class

# %% [markdown]
# Feature extraction
# #1 from text = 1 for a word and 0 for empty
# #2 from image = pixels
# tf-idf Vectorizer
#
# tf = time frequency : number of times term t appears in a document / total number of terms in a document
# idf = log(number of documents/ number of document a term t appeared in)
# tf-idf value of a term = tf * idf
